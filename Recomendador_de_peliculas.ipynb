# %% [markdown]
# <a href="https://colab.research.google.com/github/Luisinho-31/Movie_recomendator/blob/main/Recomendador_de_peliculas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aprendizaje no supervizado

# %% [markdown]
# En este colab veremos como se muestran las recomendaciones de una pelicula basado en el modelo de Content-bases recommendatios System
# este es un modelo de ML no Supervisado
# *   Informacion obtenida desde: https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata

# %% [markdown]
# ## Carga de librerias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# AUTH
from google.colab import auth
auth.authenticate_user()
from google.colab import drive
drive.mount('/content/drive')
import ast
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Carga del Dataset

# %%
df_credits = pd.read_csv('/content/drive/MyDrive/Descargas/PLAN DE ACCION/Curso - Aprendizaje no Supervizado/tmdb_5000_credits.csv')
df_movie = pd.read_csv( '/content/drive/MyDrive/Descargas/PLAN DE ACCION/Curso - Aprendizaje no Supervizado/tmdb_5000_movies.csv')

# %%
df_credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
df_movie.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
df_credits = df_credits.rename(columns={'movie_id': 'id'})
df_credits = df_credits.drop(columns=['title'])
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
# Realizamos un merge de nuestros 2 df
df_merge = pd.merge(df_movie, df_credits, on='id')
df_merge.head(5)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# ## Revisamos nulos

# %%
def missing_zero_values_table(df):
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
        return mz_table

# %%
missing_zero_values_table(df_merge)
#vemos que hay varios valores nulos o ceros pero no son variables que nos ayudaran o perjudicaran
# Out:
# Your selected dataframe has 22 columns and 4803 Rows.
# There are 5 columns that have missing values.
#               Zero Values  Missing Values  % of Total Values  \
# homepage                0            3091               64.4
# tagline                 0             844               17.6
# overview                0               3                0.1
# runtime                35               2                0.0
# release_date            0               1                0.0
#
#               Total Zero Missing Values  % Total Zero Missing Values Data Type
# homepage                           3091                         64.4    object
# tagline                             844                         17.6    object
# overview                              3                          0.1    object
# runtime                              37                          0.8   float64
# release_date                          1                          0.0    object

# %%
# df_merge[df_merge.tagline.notnull()]

# %%
df_merge.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
df = df_merge.drop(columns=['budget', 'homepage', 'original_language', 'status', 'popularity','production_companies','production_countries',
                            'release_date','release_date', 'revenue', 'runtime','spoken_languages', 'status', 'tagline',
                            'cast', 'crew','original_title'])

# %%
# df_merge.head(2)
df
# Out:
#                                                  genres      id  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...                                                 ...     ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801                                                 []  126186
# 4802                [{"id": 99, "name": "Documentary"}]   25975
#
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# ...

# %%
# vemos que mantiene una estructura id y name, solo nos importa el name
df.genres[0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
# convertimos la columna en lista
df['genres'] = df['genres'].apply(lambda x: ast.literal_eval(x))

df['genres'] = df['genres'].apply(lambda x: [d['name'] for d in x])
# df['genres_str'] = df['genres'].apply(lambda x: ' '.join(x))

# %%
df['generos_str'] = df['genres'].apply(lambda x: ' '.join(x))
df
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4798                      [Action, Crime, Thriller]    9367
# 4799                              [Comedy, Romance]   72766
# 4800             [Comedy, Drama, Romance, TV Movie]  231617
# 4801                                             []  126186
# 4802                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# ...

# %%
df[df['overview'].isna()]
# Out:
#              genres      id  \
# 2656        [Drama]  370980
# 4140  [Documentary]  459488
# 4431  [Documentary]  292539
#
#                                                keywords overview  \
# 2656  [{"id": 717, "name": "pope"}, {"id": 5565, "na...      NaN
# 4140  [{"id": 6027, "name": "music"}, {"id": 225822,...      NaN
# 4431                                                 []      NaN
#
#                                            title  vote_average  vote_count  \
# 2656  Chiamatemi Francesco - Il Papa della gente           7.3          12
# 4140                 To Be Frank, Sinatra at 100           0.0           0
# 4431                                 Food Chains           7.4           8
#
#       generos_str
# 2656        Drama
# 4140  Documentary
# 4431  Documentary

# %%
df['overview'] = df['overview'].fillna('')
df
# Out:
#                                              genres      id  \
# 0     [Action, Adventure, Fantasy, Science Fiction]   19995
# 1                      [Adventure, Fantasy, Action]     285
# 2                        [Action, Adventure, Crime]  206647
# 3                  [Action, Crime, Drama, Thriller]   49026
# 4              [Action, Adventure, Science Fiction]   49529
# ...                                             ...     ...
# 4798                      [Action, Crime, Thriller]    9367
# 4799                              [Comedy, Romance]   72766
# 4800             [Comedy, Drama, Romance, TV Movie]  231617
# 4801                                             []  126186
# 4802                                  [Documentary]   25975
#
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# ...

# %%
# juntamos la overviw junto con el genero de la pelicula, esto para obtener mas adelante resultados mas precisos en las recomendaciones
# en otro ejercicio se podria tomar actores o directores para buscar similitudes entre ellos

# %%
df['genero_reseña'] =  df['generos_str'] + ' ' + df['overview']

# %% [markdown]
# ## Modelod de recomendacion

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Eliminamos palabras (stop words) ejemplo the, and, palabras que se repiten mucho y cuasan ruido
# y vectorizamos los generos y las reseñas
vector = TfidfVectorizer(stop_words='english')
matriz_vector = vector.fit_transform(df['genero_reseña'])

# %%
# usaremos cosenos para ir comparando las distancias entre una reseña y otra
coseno_pel = cosine_similarity(matriz_vector, matriz_vector)
coseno_pel
# Out:
# array([[1.        , 0.03898534, 0.0158045 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.03898534, 1.        , 0.01754479, ..., 0.02077535, 0.        ,
#         0.        ],
#        [0.0158045 , 0.01754479, 1.        , ..., 0.01447181, 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.02077535, 0.01447181, ..., 1.        , 0.01958252,
#         0.00686099],
#        [0.        , 0.        , 0.        , ..., 0.01958252, 1.        ,
#         0.01170891],
#        [0.        , 0.        , 0.        , ..., 0.00686099, 0.01170891,
#         1.        ]])

# %%
def recomendar_peliculas(titulo, n):
  #buscamos el titulo y obtenemos el coseno de la pelicula
  indice = df[df['title']==titulo].index[0]
  distancia = coseno_pel[indice]
  #buscamos la pelicula recomendada de mayor a menor en distancia
  peliculas_recomendadas = sorted(list(enumerate(distancia)), reverse=True, key=lambda x: x[1])[1:n+1]
  movie_indices = [i[0] for i in peliculas_recomendadas]
  proximidad = [round(i[1], 5) for i in peliculas_recomendadas]
  recomendadas = df[['title', 'generos_str']].iloc[movie_indices].copy()

  recomendadas['proximidad'] = proximidad


  return recomendadas

# %%
recomendar_peliculas('Kung Fu Panda 2', 10)
#vemos que para kun fu panda 2 hay una buena coincidencia , al igual el genero es similar a los demas resultados
# Out:
#                               title                               generos_str  \
# 181                   Kung Fu Panda         Adventure Animation Family Comedy
# 2899             Legend of a Rabbit  Animation Family Action Adventure Comedy
# 2184                 Kung Fu Hustle               Action Comedy Crime Fantasy
# 894                Bulletproof Monk                     Action Comedy Fantasy
# 4220           Kickboxer: Vengeance                              Action Drama
# 152                 Kung Fu Panda 3  Action Adventure Animation Comedy Family
# 3029       Kung Pow: Enter the Fist                             Action Comedy
# 836           The Forbidden Kingdom                  Action Adventure Fantasy
# 2884                           2046     Fantasy Drama Science Fiction Romance
# 4491  The Hadza:  Last of the First                               Documentary
#
#       proximidad
# 181      0.46401
# 2899     0.38325
# 2184     0.29292
# 894      0.28807
# 4220     0.22889
# ...

# %%
df.sample(10)
# Out:
#                              genres     id  \
# 3464                [Comedy, Music]  13370
# 320          [Action, History, War]    855
# 4192                        [Drama]  32579
# 3181                [Comedy, Drama]   9685
# 527                 [Comedy, Crime]   4551
# 644   [Action, Adventure, Thriller]   9350
# 3766                [Crime, Comedy]      5
# 236   [Drama, Action, History, War]  12100
# 137             [Animation, Family]  49444
# 4193      [Action, Science Fiction]   1688
#
#                                                keywords  \
# 3464  [{"id": 11800, "name": "mockumentary"}, {"id":...
# 320   [{"id": 1968, "name": "prisoners of war"}, {"i...
# 4192  [{"id": 10183, "name": "independent film"}, {"...
# 3181  [{"id": 494, "name": "father son relationship"...
# 527   [{"id": 3605, "name": "baseball bat"}, {"id": ...
# 644   [{"id": 2805, "name": "rocky mountains"}, {"id...
# 3766  [{"id": 612, "name": "hotel"}, {"id": 613, "na...
# ...
